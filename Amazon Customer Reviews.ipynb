# %% [markdown]
# ## Eskwelabs Capstone Project: Text Analysis, Predicting Customer Reviews
#
# DATA COLUMNS:<br>
# marketplace       - 2 letter country code of the marketplace where the review was written.<br>
# customer_id       - Random identifier that can be used to aggregate reviews written by a single author.<br>
# review_id         - The unique ID of the review. <br>
# product_id        - The unique Product ID the review pertains to. In the multilingual dataset the reviews <br>
#                     for the same product in different countries can be grouped by the same product_id.
#
# product_parent    - Random identifier that can be used to aggregate reviews for the same product. <br>
# product_title     - Title of the product. <br>
# product_category  - Broad product category that can be used to group reviews <br>
#                     (also used to group the dataset into coherent parts).
#
# star_rating       - The 1-5 star rating of the review. <br>
# helpful_votes     - Number of helpful votes. <br>
# total_votes       - Number of total votes the review received. <br>
# vine              - Review was written as part of the Vine program. <br>
# verified_purchase - The review is on a verified purchase. <br>
# review_headline   - The title of the review. <br>
# review_body       - The review text. <br>
# review_date       - The date the review was written. <br>

# %% [markdown]
# **The problem I am solving is best framed as a clustering problem (unsupervised), which predicts whether a product can be grouped with other products that will more likely for other customers to buy** <br>
# - I have the Amazon Customer Reviews data set that hosts more than a million rows from 2015 for different categoriess of products. <br>
# - SO YOU MIGHT ASK ME, WHAT'S SO SPECIAL ABOUT THIS DATASET? <br>
# - This dataset can be considered as big data, and I look forward to analyzing data that are big as this dataset. This dataset also has a text data in which I can analyze by using Natural Language Processing, that has been really interesting for me. These 2 components of big data and unstructured data are, on my opinion, relevant to the current environment of data science in the Philippines. <br>
# - My ideal outcome for this project is to recommend a product that a customer will buy, however my model will not provide a ranking model but only a clustering model. I am aware of the limitation of my model and I have accepted it by transforming the clusters of product into possible marketing campaigns, with the testimonials of the customers who had reviewed it.

# %% [markdown]
# ## Data Preparation

# %%
# Load necessary modules I will use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning modules
import sklearn.preprocessing

# %%
cust_reviews = pd.read_csv('sample_us.tsv', sep='\t')
cust_reviews
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0           US     18778586   RDIJS7QYB6XNR  B00EDBY7X8       122952789
# 1           US     24769659  R36ED1U38IELG8  B00D7JFOPC       952062646
# 2           US     44331596   R1UE3RPRGCOLD  B002LHA74O       818126353
# 3           US     23310293  R298788GS6I901  B00ARPLCGY       261944918
# 4           US     38745832    RNX4EXOBBPN5  B00UZOPOFW       717410439
# 5           US     13394189  R3BPETL222LMIM  B009B7F6CA       873028700
# 6           US      2749569  R3SORMPJZO3F2J  B0101EHRSM       723424342
# 7           US     41137196  R2RDOJQ0WBZCF6  B00407S11Y       383363775
# 8           US       433677  R2B8VBEPB4YEZ7  B00FGPU7U2       780517568
# 9           US      1297934  R1CB783I7B0U52  B0013OY0S0       269360126
# 10          US     52006292   R2D90RQQ3V8LH  B00519PJTW       493486387
# 11          US     32071052  R1Y4ZOUGFMJ327  B001TCY2DO       459122467
# ...
